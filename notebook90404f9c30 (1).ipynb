# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
train = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/train.csv")
test = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/test.csv")

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.shape
# Out:
# (1460, 81)

# %%
train

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False)

# %%
train.shape
# Out:
# (1460, 81)

# %%
train.info

# %%
train['LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean())

# %%
train.drop(['Alley'],axis=1,inplace=True)

# %%
test.drop(['Alley'],axis=1,inplace=True)

# %%
test.shape
# Out:
# (1459, 79)

# %%
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])

# %%
test['BsmtCond']=test['BsmtCond'].fillna(test['BsmtCond'].mode()[0])
test['BsmtQual']=test['BsmtQual'].fillna(test['BsmtQual'].mode()[0])

# %%
train['FireplaceQu']=train['FireplaceQu'].fillna(train['FireplaceQu'].mode()[0])
train['GarageType']=train['GarageType'].fillna(train['GarageType'].mode()[0])

# %%
test['FireplaceQu']=test['FireplaceQu'].fillna(test['FireplaceQu'].mode()[0])
test['GarageType']=test['GarageType'].fillna(test['GarageType'].mode()[0])

# %%
train.drop(['GarageYrBlt'],axis=1,inplace=True)

# %%
test.drop(['GarageYrBlt'],axis=1,inplace=True)

# %%
test.shape
# Out:
# (1459, 78)

# %%
train['GarageQual']=train['GarageQual'].fillna(train['GarageQual'].mode()[0])
train['GarageFinish']=train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])
train['GarageCond']=train['GarageCond'].fillna(train['GarageCond'].mode()[0])

# %%
test['GarageQual']=test['GarageQual'].fillna(test['GarageQual'].mode()[0])
test['GarageFinish']=test['GarageFinish'].fillna(test['GarageFinish'].mode()[0])
test['GarageCond']=test['GarageCond'].fillna(test['GarageCond'].mode()[0])

# %%
train.drop(['PoolQC','Fence', 'MiscFeature'],axis=1,inplace=True)

# %%
test.drop(['PoolQC','Fence', 'MiscFeature'],axis=1,inplace=True)

# %%
test.shape
# Out:
# (1459, 75)

# %%
train.shape
# Out:
# (1460, 76)

# %%
test['LotFrontage']=test['LotFrontage'].fillna(test['LotFrontage'].mean())

# %%
test['MSZoning']=test['MSZoning'].fillna(test['MSZoning'].mode()[0])

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.drop(['Id'],axis=1,inplace=True)

# %%
test.drop(['Id'],axis=1,inplace=True)

# %%
train.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
train['MasVnrType']=train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])
train['MasVnrArea']=train['MasVnrArea'].fillna(train['MasVnrArea'].mode()[0])

# %%
test['MasVnrType']=test['MasVnrType'].fillna(test['MasVnrType'].mode()[0])
test['MasVnrArea']=test['MasVnrArea'].fillna(test['MasVnrArea'].mode()[0])

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')

# %%
train['BsmtFinType2']=train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])

# %%
test['BsmtFinType2']=test['BsmtFinType2'].fillna(test['BsmtFinType2'].mode()[0])

# %%
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])

# %%
test['BsmtExposure']=test['BsmtExposure'].fillna(test['BsmtExposure'].mode()[0])

# %%
train.shape
# Out:
# (1460, 75)

# %%
train.dropna(inplace=True)

# %%
train.shape
# Out:
# (1422, 75)

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0        0       0       2    2008        WD         Normal    208500
# 1        0       0       5    2007        WD         Normal    181500
# 2        0       0       9    2008        WD         Normal    223500
# 3        0       0       2    2006        WD        Abnorml    140000
# 4        0       0      12    2008        WD         Normal    250000
#
# [5 rows x 75 columns]

# %%
test.shape
# Out:
# (1459, 74)

# %%
test['Utilities']=test['Utilities'].fillna(test['Utilities'].mode()[0])
test['Exterior1st']=test['Exterior1st'].fillna(test['Exterior1st'].mode()[0])
test['Exterior2nd']=test['Exterior2nd'].fillna(test['Exterior2nd'].mode()[0])
test['BsmtFinType1']=test['BsmtFinType1'].fillna(test['BsmtFinType1'].mode()[0])
test['BsmtFinSF1']=test['BsmtFinSF1'].fillna(test['BsmtFinSF1'].mean())
test['BsmtFinSF2']=test['BsmtFinSF2'].fillna(test['BsmtFinSF2'].mean())
test['BsmtUnfSF']=test['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mean())
test['TotalBsmtSF']=test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].mean())
test['BsmtFullBath']=test['BsmtFullBath'].fillna(test['BsmtFullBath'].mode()[0])
test['BsmtHalfBath']=test['BsmtHalfBath'].fillna(test['BsmtHalfBath'].mode()[0])
test['KitchenQual']=test['KitchenQual'].fillna(test['KitchenQual'].mode()[0])
test['Functional']=test['Functional'].fillna(test['Functional'].mode()[0])
test['GarageCars']=test['GarageCars'].fillna(test['GarageCars'].mean())
test['GarageArea']=test['GarageArea'].fillna(test['GarageArea'].mean())
test['SaleType']=test['SaleType'].fillna(test['SaleType'].mode()[0])

# %%
test.shape
# Out:
# (1459, 74)

# %%
test.to_csv('formulatedtest.csv',index=False)

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0        0       0       2    2008        WD         Normal    208500
# 1        0       0       5    2007        WD         Normal    181500
# 2        0       0       9    2008        WD         Normal    223500
# 3        0       0       2    2006        WD        Abnorml    140000
# 4        0       0      12    2008        WD         Normal    250000
#
# [5 rows x 75 columns]

# %%
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

# %%
len(columns)
# Out:
# 39

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
main_train=train.copy()

# %%
test=pd.read_csv('formulatedtest.csv')

# %%
test.shape
# Out:
# (1459, 74)

# %%
test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0    AllPub    Inside       Gtl  ...           0             0         0
# 1    AllPub    Corner       Gtl  ...          36             0         0
# 2    AllPub    Inside       Gtl  ...          34             0         0
# 3    AllPub    Inside       Gtl  ...          36             0         0
# 4    AllPub    Inside       Gtl  ...          82             0         0
#
#   ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition
# 0         120        0        0       6    2010        WD        Normal
# 1           0        0    12500       6    2010        WD        Normal
# 2           0        0        0       3    2010        WD        Normal
# 3           0        0        0       6    2010        WD        Normal
# 4         144        0        0       1    2010        WD        Normal
#
# [5 rows x 74 columns]

# %%
final_df=pd.concat([train,test],axis=0)

# %%
final_df['SalePrice']
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1454         NaN
# 1455         NaN
# 1456         NaN
# 1457         NaN
# 1458         NaN
# Name: SalePrice, Length: 2881, dtype: float64

# %%
final_df.shape
# Out:
# (2881, 75)

# %%
final_df=category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %%
final_df.shape
# Out:
# (2881, 234)

# %%
final_df =final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2881, 174)

# %%
final_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...   Min1   Min2  \
# 0             2003       196.0       706.0         0.0  ...  False  False
# 1             1976         0.0       978.0         0.0  ...  False  False
# 2             2002       162.0       486.0         0.0  ...  False  False
# 3             1970         0.0       216.0         0.0  ...  False  False
# 4             2000       350.0       655.0         0.0  ...  False  False
# ...            ...         ...         ...         ...  ...    ...    ...
# 1454          1970         0.0         0.0         0.0  ...  False  False
# 1455          1970         0.0       252.0         0.0  ...  False  False
# 1456          1996         0.0      1224.0         0.0  ...  False  False
# 1457          1992         0.0       337.0         0.0  ...  False  False
# 1458          1994        94.0       758.0         0.0  ...  False  False
#
#        Typ  Attchd  Basment  BuiltIn  CarPort  Detchd    RFn      P
# 0     True    True    False    False    False   False   True  False
# 1     True    True    False    False    False   False   True  False
# 2     True    True    False    False    False   False   True  False
# 3     True   False    False    False    False    True  False  False
# 4     True    True    False    False    False   False   True  False
# ...    ...     ...      ...      ...      ...     ...    ...    ...
# 1454  True    True    False    False    False   False  False  False
# 1455  True   False    False    False     True   False  False  False
# 1456  True   False    False    False    False    True  False  False
# 1457  True    True    False    False    False   False  False  False
# 1458  True    True    False    False    False   False  False  False
#
# [2881 rows x 174 columns]

# %%
df_Train=final_df.iloc[:1422,:]
df_Test=final_df.iloc[1422:,:]

# %%
df_Train.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...   Min1   Min2   Typ  \
# 0          2003       196.0       706.0         0.0  ...  False  False  True
# 1          1976         0.0       978.0         0.0  ...  False  False  True
# 2          2002       162.0       486.0         0.0  ...  False  False  True
# 3          1970         0.0       216.0         0.0  ...  False  False  True
# 4          2000       350.0       655.0         0.0  ...  False  False  True
#
#    Attchd  Basment  BuiltIn  CarPort  Detchd    RFn      P
# 0    True    False    False    False   False   True  False
# 1    True    False    False    False   False   True  False
# 2    True    False    False    False   False   True  False
# 3   False    False    False    False    True  False  False
# 4    True    False    False    False   False   True  False
#
# [5 rows x 174 columns]

# %%
df_Test.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          20         80.0    11622            5            6       1961
# 1          20         81.0    14267            6            6       1958
# 2          60         74.0    13830            5            5       1997
# 3          60         78.0     9978            6            6       1998
# 4         120         43.0     5005            8            5       1992
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...   Min1   Min2   Typ  \
# 0          1961         0.0       468.0       144.0  ...  False  False  True
# 1          1958       108.0       923.0         0.0  ...  False  False  True
# 2          1998         0.0       791.0         0.0  ...  False  False  True
# 3          1998        20.0       602.0         0.0  ...  False  False  True
# 4          1992         0.0       263.0         0.0  ...  False  False  True
#
#    Attchd  Basment  BuiltIn  CarPort  Detchd    RFn      P
# 0    True    False    False    False   False  False  False
# 1    True    False    False    False   False  False  False
# 2    True    False    False    False   False  False  False
# 3    True    False    False    False   False  False  False
# 4    True    False    False    False   False   True  False
#
# [5 rows x 174 columns]

# %%
df_Train.shape
# Out:
# (1422, 174)

# %%
df_Test.shape
# Out:
# (1459, 174)

# %%
df_Test.to_excel('df_Test.xlsx', index=False)

# %%
df_Test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /tmp/ipykernel_42/3985304647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Test.drop(['SalePrice'],axis=1,inplace=True)

# %%
df_Test.shape
# Out:
# (1459, 173)

# %%
X_train=df_Train.drop(['SalePrice'],axis=1)
y_train=df_Train['SalePrice']

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

# %%
import xgboost
from sklearn.model_selection import RandomizedSearchCV
classifier=xgboost.XGBRegressor()
import xgboost
regressor=xgboost.XGBRegressor()
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:27] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:31] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:31] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:25:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:36] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:26:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:36] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:27:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=1500;, score=(train=-16405.304, test=-22377.231) total time=   5.9s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-2189.425, test=-16662.812) total time=   4.2s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-2524.208, test=-14091.488) total time=   4.1s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-15694.209, test=-21410.763) total time=   2.1s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-11.569, test=-14479.159) total time=  15.6s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3542.212, test=-17049.887) total time=   4.6s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-18247.103, test=-18260.972) total time=   0.6s
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-17390.555, test=-21790.322) total time=   0.6s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-17017.435, test=-22642.217) total time=   0.6s
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-18119.844, test=-19132.616) total time=   0.6s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2774.520, test=-16161.061) total time=   4.6s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2812.611, test=-19680.747) total time=   5.0s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-13.576, test=-14527.995) total time=   7.4s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-6828.581, test=-16826.943) total time=   3.1s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-7.345, test=-15273.828) total time=  16.4s
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-17037.720, test=-21630.767) total time=   3.9s
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-15514.217, test=-21553.312) total time=   3.7s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-583.659, test=-17784.036) total time=   6.2s
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-17056.176, test=-21677.447) total time=   2.2s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-17569.314, test=-19585.791) total time=   2.1s
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-17050.834, test=-22929.517) total time=   2.2s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-7.364, test=-17804.339) total time=  27.8s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.05, max_depth=2, min_child_weight=4, n_estimators=900;, score=(train=-9317.093, test=-17445.679) total time=   2.8s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.05, max_depth=2, min_child_weight=4, n_estimators=900;, score=(train=-8880.507, test=-17644.975) total time=   2.8s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-908.297, test=-17508.540) total time=   3.5s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1280.851, test=-16572.985) total time=   1.7s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1675.776, test=-17524.805) total time=   1.7s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1759.232, test=-18233.407) total time=   1.5s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-16504.877, test=-22362.470) total time=   3.7s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-15514.216, test=-21553.312) total time=   3.8s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-7.320, test=-15814.447) total time=  10.2s
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-16611.146, test=-22128.567) total time=   0.6s
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-16504.873, test=-22362.462) total time=   3.7s
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-18579.519, test=-22925.216) total time=   0.6s
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-19066.192, test=-19773.046) total time=   0.6s
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-19236.471, test=-19237.628) total time=   0.6s
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-18165.982, test=-23289.781) total time=   0.6s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-17537.445, test=-22698.814) total time=   0.6s
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-17786.408, test=-19200.224) total time=   3.8s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=100;, score=(train=-4403.129, test=-16880.581) total time=   0.8s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-7.332, test=-16755.904) total time=  37.2s
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=500;, score=(train=-17050.834, test=-22929.520) total time=   2.2s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-18683.597, test=-18705.228) total time=   0.6s
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-17932.356, test=-22428.871) total time=   0.6s
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-18528.307, test=-19502.014) total time=   0.6s
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:28:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:31] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:29:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=1500;, score=(train=-16949.083, test=-21491.089) total time=   5.9s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-2254.015, test=-15572.884) total time=   4.3s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-17888.761, test=-18287.758) total time=   2.1s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-16651.262, test=-22535.046) total time=   2.2s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-17.984, test=-17669.982) total time=  14.9s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3733.357, test=-15896.984) total time=   4.7s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3768.304, test=-14523.915) total time=   4.7s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-16471.808, test=-22067.875) total time=   0.6s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2726.822, test=-17600.958) total time=   4.7s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-14.089, test=-16867.281) total time=   6.9s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-129.860, test=-17722.139) total time=   5.3s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-7.344, test=-16278.342) total time=  16.1s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-0.055, test=-18515.981) total time=  15.4s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-551.972, test=-17130.412) total time=   5.6s
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-17401.934, test=-22091.095) total time=   2.1s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-7.384, test=-17219.344) total time=  23.0s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-0.064, test=-18982.753) total time=  26.6s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-0.129, test=-18277.041) total time=   9.4s
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-18423.725, test=-18386.779) total time=   0.6s
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-17598.335, test=-22061.260) total time=   0.6s
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-17223.496, test=-22825.744) total time=   0.6s
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-17755.783, test=-18671.543) total time=   3.8s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-19236.467, test=-19237.628) total time=   0.6s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-18165.980, test=-23289.776) total time=   0.6s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-17537.441, test=-22698.811) total time=   0.6s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-18579.520, test=-22925.215) total time=   0.6s
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-19066.190, test=-19773.036) total time=   0.6s
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-17962.765, test=-18329.592) total time=   3.8s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-15782.776, test=-21456.556) total time=   3.8s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-7.332, test=-15333.845) total time=  31.7s
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=500;, score=(train=-18209.512, test=-18414.851) total time=   2.3s
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=500;, score=(train=-17401.935, test=-22091.096) total time=   2.2s
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=500;, score=(train=-16188.327, test=-21852.729) total time=   2.2s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-16866.815, test=-22302.618) total time=   0.6s
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=-16549.981, test=-22404.805) total time=   2.3s
# [CV 1/5] END base_score=0.75, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=500;, score=(train=-7466.899, test=-15551.629) total time=   1.9s
# [CV 2/5] END base_score=0.75, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=500;, score=(train=-7400.929, test=-17902.646) total time=   1.7s
# [CV 5/5] END base_score=0.75, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=500;, score=(train=-7183.188, test=-18244.188) total time=   1.7s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=1500;, score=(train=-7.326, test=-18201.316) total time=  30.8s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-16949.081, test=-21491.087) total time=   6.2s
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-17417.084, test=-20138.202) total time=   6.2s
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=1500;, score=(train=-17043.897, test=-21780.844) total time=   6.4s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=1500;, score=(train=-15568.418, test=-21354.209) total time=   6.3s
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=1, n_estimators=1100;, score=(train=-17028.328, test=-21570.130) total time=   4.8s
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=1, n_estimators=1100;, score=(train=-15507.026, test=-21627.492) total time=   5.2s
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=1500;, score=(train=-17417.086, test=-20138.202) total time=   5.9s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-2252.240, test=-17348.653) total time=   4.2s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-2327.879, test=-18090.287) total time=   4.1s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-11.163, test=-16380.983) total time=  16.3s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3541.630, test=-17774.702) total time=   4.7s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3634.891, test=-18867.055) total time=   4.8s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2755.911, test=-17665.436) total time=   4.6s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-20.151, test=-17690.227) total time=   6.5s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-7104.074, test=-17446.037) total time=   3.6s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-7000.889, test=-16359.836) total time=   3.0s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-0.045, test=-17772.694) total time=  16.1s
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-17755.783, test=-18671.543) total time=   3.9s
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-17524.085, test=-19767.068) total time=   3.6s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-559.115, test=-17067.742) total time=   6.5s
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-17795.025, test=-18603.347) total time=   2.2s
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-16541.433, test=-22402.934) total time=   2.2s
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-18209.512, test=-18414.848) total time=   2.1s
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-16188.328, test=-21852.731) total time=   2.2s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-7.366, test=-15648.170) total time=  29.9s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.05, max_depth=2, min_child_weight=4, n_estimators=900;, score=(train=-9663.072, test=-14011.115) total time=   2.9s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-863.678, test=-17755.480) total time=   3.6s
# [CV 5/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-948.713, test=-18180.406) total time=   3.6s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1536.138, test=-15179.757) total time=   1.7s
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-17037.723, test=-21630.766) total time=   3.7s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-7.418, test=-16277.068) total time=   9.3s
# [CV 5/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-0.058, test=-17883.721) total time=   8.4s
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-17524.085, test=-19767.068) total time=   3.7s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-17139.844, test=-21857.904) total time=   3.8s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=100;, score=(train=-4542.011, test=-16011.288) total time=   0.8s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=100;, score=(train=-4689.793, test=-13900.206) total time=   0.8s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-7.326, test=-17561.836) total time=  38.0s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=500;, score=(train=-18083.716, test=-19177.627) total time=   2.1s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-17534.950, test=-23058.953) total time=   0.6s
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=-17797.381, test=-18453.475) total time=   2.1s
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=-17585.117, test=-19402.486) total time=   2.9s
# [CV 4/5] END base_score=0.75, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=500;, score=(train=-7833.416, test=-14002.314) total time=   1.7s
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-18579.514, test=-22925.206) total time=   0.6s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-19066.190, test=-19773.041) total time=   0.6s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=1500;, score=(train=-7.341, test=-16277.125) total time=  24.3s
# [CV 5/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=1500;, score=(train=-0.029, test=-17883.673) total time=  28.5s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=900;, score=(train=-1005.328, test=-17799.283) total time=   3.4s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=1, n_estimators=1100;, score=(train=-17737.149, test=-18738.175) total time=   5.2s
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-17797.381, test=-18453.475) total time=   2.4s
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-17585.117, test=-19402.486) total time=   2.5s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=500;, score=(train=-405.757, test=-17386.223) total time=   3.2s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=100;, score=(train=-14020.600, test=-16697.329) total time=   0.6s
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:16] WARNING: /workspace/src/learner.cc:742:
# ...
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-17701.637, test=-19191.762) total time=   2.1s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-42.017, test=-17129.022) total time=  12.7s
# [CV 5/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-47.108, test=-18334.143) total time=  12.0s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2715.497, test=-13752.023) total time=   4.8s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-78.709, test=-17666.122) total time=   5.4s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-7248.697, test=-15587.359) total time=   3.7s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-7486.190, test=-14192.163) total time=   2.9s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-7.337, test=-17885.166) total time=  18.4s
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-16504.873, test=-22362.462) total time=   3.9s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-610.255, test=-15668.767) total time=   6.2s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-572.356, test=-14324.609) total time=   5.8s
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-15557.471, test=-21479.410) total time=   2.1s
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-18083.718, test=-19177.628) total time=   2.2s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-0.073, test=-18419.916) total time=  25.9s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.05, max_depth=2, min_child_weight=4, n_estimators=900;, score=(train=-9310.739, test=-15100.388) total time=   2.8s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.05, max_depth=2, min_child_weight=4, n_estimators=900;, score=(train=-9289.584, test=-17467.463) total time=   2.8s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-984.731, test=-16320.626) total time=   3.5s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-944.908, test=-14738.229) total time=   3.5s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1358.678, test=-17897.715) total time=   1.8s
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-17755.785, test=-18671.547) total time=   3.7s
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-17524.084, test=-19767.068) total time=   3.7s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-7.330, test=-18201.425) total time=  11.5s
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-18270.872, test=-19307.866) total time=   0.6s
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-17037.720, test=-21630.767) total time=   3.6s
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-15514.217, test=-21553.312) total time=   3.8s
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-16738.020, test=-22608.630) total time=   3.8s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=100;, score=(train=-4307.370, test=-17087.288) total time=   0.8s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=100;, score=(train=-4793.587, test=-18572.938) total time=   0.8s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-0.037, test=-18087.112) total time=  23.1s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-0.032, test=-18458.510) total time=  26.6s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=1500;, score=(train=-7.319, test=-15814.433) total time=  37.5s
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-15509.981, test=-21810.070) total time=   6.2s
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=1500;, score=(train=-17610.944, test=-19382.851) total time=   6.0s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=900;, score=(train=-955.987, test=-17275.426) total time=   3.5s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=900;, score=(train=-951.400, test=-15250.761) total time=   3.6s
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=1, n_estimators=1100;, score=(train=-16490.545, test=-22364.933) total time=   5.4s
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-17029.802, test=-21722.786) total time=   2.5s
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-15567.435, test=-21401.189) total time=   2.4s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=500;, score=(train=-319.483, test=-14083.981) total time=   3.3s
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-17037.723, test=-21630.772) total time=   4.0s
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-17755.823, test=-18604.958) total time=   4.6s
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-15509.218, test=-21460.828) total time=   4.7s
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:30:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:31:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_depth", "min_child_weight" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                           num_parallel_tree=None,
#                                           random_state=None, ...),
#                    n_iter=50, n_jobs=4,
#                    param_distributions={'base_score': [0.25, 0.5, 0.75, 1],
#                                         'booster': ['gbtree', 'gblinear'],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2],
#                                         'max_depth': [2, 3, 5, 10, 15],
#                                         'min_child_weight': [1, 2, 3, 4],
#                                         'n_estimators': [100, 500, 900, 1100,
#                                                          1500]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_mean_absolute_error', verbose=5)

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
regressor=xgboost.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)

# %%
regressor.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:33:22] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:33:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=None, colsample_bytree=1,
#              device=None, early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=0, max_depth=2,
#              max_leaves=None, min_child_weight=1, missing=None,
#              monotone_constraints=None, multi_strategy=None, n_estimators=900,
#              n_jobs=1, nthread=None, num_parallel_tree=None, ...)

# %%
import pickle
filename = 'finalized_model.pkl'
pickle.dump(classifier, open(filename, 'wb'))

# %%
df_Test.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          20         80.0    11622            5            6       1961
# 1          20         81.0    14267            6            6       1958
# 2          60         74.0    13830            5            5       1997
# 3          60         78.0     9978            6            6       1998
# 4         120         43.0     5005            8            5       1992
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...   Min1   Min2   Typ  \
# 0          1961         0.0       468.0       144.0  ...  False  False  True
# 1          1958       108.0       923.0         0.0  ...  False  False  True
# 2          1998         0.0       791.0         0.0  ...  False  False  True
# 3          1998        20.0       602.0         0.0  ...  False  False  True
# 4          1992         0.0       263.0         0.0  ...  False  False  True
#
#    Attchd  Basment  BuiltIn  CarPort  Detchd    RFn      P
# 0    True    False    False    False   False  False  False
# 1    True    False    False    False   False  False  False
# 2    True    False    False    False   False  False  False
# 3    True    False    False    False   False  False  False
# 4    True    False    False    False   False   True  False
#
# [5 rows x 173 columns]

# %%
df_Test.isnull().sum()
# Out:
# MSSubClass     0
# LotFrontage    0
# LotArea        0
# OverallQual    0
# OverallCond    0
#               ..
# BuiltIn        0
# CarPort        0
# Detchd         0
# RFn            0
# P              0
# Length: 173, dtype: int64

# %%
df_Test_imputed = df_Test.fillna(df_Train.mean())

# %%
regressor.set_params(missing=df_Train.mean().values[0])
y_pred=regressor.predict(df_Test_imputed)
# Out:
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [14:48:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
y_pred
# Out:
# array([118891.4  , 160515.81 , 184719.48 , ..., 171136.38 , 120518.234,
#        235145.02 ], dtype=float32)

# %%
predictions_df = pd.DataFrame({'SalePrice': y_pred})
sub_df=pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv')
result_df = pd.concat([sub_df['Id'], predictions_df], axis=1)
result_df.columns=['Id','SalePrice']
result_df.to_csv('predictions.csv', index=False)

# %%
b =pd.read_csv('/kaggle/working/predictions.csv')

# %%
b
# Out:
#         Id   SalePrice
# 0     1461  118891.400
# 1     1462  160515.810
# 2     1463  184719.480
# 3     1464  190003.470
# 4     1465  191538.500
# ...    ...         ...
# 1454  2915   86445.980
# 1455  2916   65611.375
# 1456  2917  171136.380
# 1457  2918  120518.234
# 1458  2919  235145.020
#
# [1459 rows x 2 columns]

# %%
import xgboost as xgb
print(xgb.__version__)
# Out:
# 2.0.3
